# %%
import jieba
words = open('201811月.text',"r").read()
jieba.add_word('一带一路')
jieba.add_word('改革开放')
jieba.add_word('人类命运共同体')
jieba.add_word('大湾区')
jieba.add_word('习近平新时代中国特色社会主义思想')
words = jieba.cut(words)
filepath = 'stopwords-zh.txt'
stopwords = [line.strip() for line in open(filepath, 'r', encoding='utf-8').readlines()]
#remove stopwords
processed_word_list = []
for word in words:
    if word not in stopwords and len(word)>1: #remove single word
        processed_word_list.append(word)
wordcount={}
for word in processed_word_list:
    if word not in wordcount:
        wordcount[word] = 1
    else:
        wordcount[word] += 1
import operator
sorted_wordcount = sorted(wordcount.items(), key=operator.itemgetter(1),reverse=True)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/b8/_kzw7zqj14qdx37ndmhww0zc0000gn/T/jieba.cache
# Loading model cost 1.046 seconds.
# Prefix dict has been built succesfully.

# %%
sorted_wordcount
# Out:
# [('中国', 5544),
#  ('发展', 4738),
#  ('合作', 2771),
#  ('经济', 2753),
#  ('习近平', 2376),
#  ('主席', 1714),
#  ('世界', 1573),
#  ('国家', 1562),
#  ('推动', 1401),
#  ('国际', 1359),
#  ('企业', 1315),
#  ('建设', 1248),
#  ('重要', 1077),
#  ('加强', 1023),
#  ('开放', 1011),
#  ('2018', 961),
#  ('关系', 959),
#  ('共同', 955),
#  ('工作', 953),
#  ('支持', 928),
#  ('领域', 917),
#  ('问题', 889),
#  ('人民', 879),
#  ('民营企业', 864),
#  ('改革', 837),
#  ('创新', 815),
#  ('双方', 804),
#  ('表示', 803),
#  ('全球', 790),
#  ('人民日报', 778),
#  ('坚持', 767),
#  ('推进', 764),
#  ('改革开放', 739),
#  ('政策', 701),
#  ('中方', 701),
#  ('促进', 694),
#  ('全面', 685),
#  ('实现', 682),
#  ('记者', 667),
#  ('进口', 663),
#  ('一带一路', 655),
#  ('地区', 640),
#  ('服务', 630),
#  ('民营', 616),
#  ('领导人', 594),
#  ('市场', 587),
#  ('党支部', 586),
#  ('各国', 579),
#  ('博览会', 571),
#  ('上海', 563),
#  ('进一步', 552),
#  ('时代', 552),
#  ('贸易', 544),
#  ('一个', 542),
#  ('增长', 538),
#  ('进行', 535),
#  ('投资', 535),
#  ('总书记', 533),
#  ('总理', 531),
#  ('社会', 530),
#  ('积极', 529),
#  ('日电', 516),
#  ('会议', 512),
#  ('交流', 511),
#  ('提供', 510),
#  ('不断', 509),
#  ('深化', 504),
#  ('历史', 497),
#  ('组织', 490),
#  ('北京', 486),
#  ('继续', 482),
#  ('成为', 476),
#  ('战略', 471),
#  ('环境', 471),
#  ('更加', 468),
#  ('强调', 464),
#  ('我国', 464),
#  ('制度', 454),
#  ('出席', 435),
#  ('开展', 431),
#  ('作用', 430),
#  ('巴新', 427),
#  ('提升', 421),
#  ('岛国', 416),
#  ('会见', 412),
#  ('科技', 406),
#  ('维护', 401),
#  ('东盟', 397),
#  ('产业', 393),
#  ('稳定', 393),
#  ('落实', 392),
#  ('指出', 391),
#  ('持续', 390),
#  ('方面', 386),
#  ('重大', 385),
#  ('新华社', 382),
#  ('建立', 380),
#  ('政治', 378),
#  ('项目', 376),
#  ('全球化', 376),
#  ('共建', 367),
#  ('西班牙', 367),
#  ('治理', 364),
#  ('文化', 361),
#  ('今年', 358),
#  ('提出', 355),
#  ('扩大', 354),
#  ('取得', 352),
#  ('发挥', 345),
#  ('未来', 344),
#  ('作出', 344),
#  ('体系', 339),
#  ('本报', 337),
#  ('坚定', 336),
#  ('精神', 334),
#  ('两国', 334),
#  ('举行', 332),
#  ('要求', 332),
#  ('技术', 331),
#  ('机制', 328),
#  ('深入', 326),
#  ('区域', 324),
#  ('基础', 321),
#  ('总统', 320),
#  ('机遇', 319),
#  ('学习', 317),
#  ('解决', 315),
#  ('平台', 312),
#  ('政府', 310),
#  ('李克强', 310),
#  ('完善', 308),
#  ('首届', 306),
#  ('企业家', 306),
#  ('领导', 305),
#  ('构建', 304),
#  ('群众', 304),
#  ('希望', 304),
#  ('参加', 303),
#  ('成果', 301),
#  ('和平', 298),
#  ('加快', 296),
#  ('党中央', 293),
#  ('全国', 289),
#  ('提高', 288),
#  ('菲律宾', 286),
#  ('文莱', 286),
#  ('同志', 283),
#  ('协调', 282),
#  ('当前', 281),
#  ('这是', 278),
#  ('访问', 277),
#  ('带来', 276),
#  ('互利', 273),
#  ('特色', 272),
#  ('实施', 271),
#  ('博会', 270),
#  ('产品', 269),
#  ('安全', 268),
#  ('部门', 268),
#  ('贡献', 268),
#  ('党员', 265),
#  ('太平洋', 262),
#  ('中心', 262),
#  ('融资', 261),
#  ('机构', 259),
#  ('情况', 259),
#  ('书记', 259),
#  ('增强', 257),
#  ('城市', 257),
#  ('本报记者', 256),
#  ('管理', 256),
#  ('包容', 256),
#  ('论坛', 255),
#  ('举办', 254),
#  ('举措', 252),
#  ('国务院', 252),
#  ('主要', 251),
#  ('活动', 249),
#  ('委员会', 248),
#  ('峰会', 247),
#  ('引领', 246),
#  ('能力', 246),
#  ('多边', 246),
#  ('发表', 243),
#  ('保持', 243),
#  ('参与', 243),
#  ('没有', 240),
#  ('建交', 240),
#  ('努力', 238),
#  ('创造', 238),
#  ('打造', 237),
#  ('水平', 236),
#  ('教育', 236),
#  ('相关', 235),
#  ('阿根廷', 235),
#  ('中央', 233),
#  ('核心', 233),
#  ('代表', 232),
#  ('倡议', 230),
#  ('金融', 229),
#  ('务实', 229),
#  ('挑战', 226),
#  ('友好', 226),
#  ('演讲', 226),
#  ('新加坡', 225),
#  ('共享', 224),
#  ('旅游', 224),
#  ('干部', 223),
#  ('健康', 221),
#  ('时间', 221),
#  ('更好', 221),
#  ('具有', 220),
#  ('社会主义', 220),
#  ('始终', 220),
#  ('高质量', 219),
#  ('特别', 219),
#  ('研究', 218),
#  ('帮助', 218),
#  ('经验', 217),
#  ('欢迎', 217),
#  ('需要', 215),
#  ('营商', 214),
#  ('形成', 213),
#  ('任务', 213),
#  ('公司', 212),
#  ('对外开放', 212),
#  ('各方', 211),
#  ('基本', 209),
#  ('原则', 208),
#  ('周年', 207),
#  ('繁荣', 207),
#  ('目前', 206),
#  ('已经', 206),
#  ('期待', 204),
#  ('伟大', 204),
#  ('自由贸易', 203),
#  ('地方', 202),
#  ('体制', 202),
#  ('思想', 200),
#  ('成立', 199),
#  ('保护', 199),
#  ('道路', 199),
#  ('规划', 196),
#  ('动力', 196),
#  ('最大', 196),
#  ('年来', 196),
#  ('两国关系', 196),
#  ('愿同', 196),
#  ('重点', 195),
#  ('基础设施', 195),
#  ('困难', 195),
#  ('认为', 195),
#  ('正在', 194),
#  ('理念', 194),
#  ('方式', 192),
#  ('一定', 192),
#  ('重要讲话', 192),
#  ('保障', 189),
#  ('共识', 189),
#  ('利益', 188),
#  ('扶贫', 188),
#  ('进入', 186),
#  ('把握', 185),
#  ('风险', 185),
#  ('超过', 185),
#  ('集团', 185),
#  ('责任', 185),
#  ('会晤', 185),
#  ('携手', 184),
#  ('召开', 184),
#  ('签署', 182),
#  ('消防', 182),
#  ('第一', 181),
#  ('变革', 180),
#  ('国事访问', 180),
#  ('行动', 180),
#  ('方向', 179),
#  ('交往', 178),
#  ('完成', 177),
#  ('15', 177),
#  ('生活', 176),
#  ('应对', 176),
#  ('事业', 176),
#  ('拓展', 176),
#  ('开放型', 176),
#  ('期间', 175),
#  ('活力', 174),
#  ('引导', 174),
#  ('亿元', 174),
#  ('农业', 173),
#  ('信心', 172),
#  ('空间', 171),
#  ('主旨', 170),
#  ('优势', 169),
#  ('基层', 168),
#  ('部署', 168),
#  ('生产', 167),
#  ('更大', 167),
#  ('优化', 166),
#  ('升级', 166),
#  ('鼓励', 166),
#  ('应该', 166),
#  ('高水平', 165),
#  ('全国政协', 165),
#  ('对话', 165),
#  ('一道', 164),
#  ('友谊', 164),
#  ('战略伙伴', 163),
#  ('开幕式', 163),
#  ('队伍', 162),
#  ('伙伴', 162),
#  ('强化', 161),
#  ('沟通', 161),
#  ('突出', 160),
#  ('生态', 160),
#  ('目标', 160),
#  ('香港', 160),
#  ('亚太', 160),
#  ('进程', 159),
#  ('应当', 159),
#  ('规则', 159),
#  ('措施', 158),
#  ('标准', 158),
#  ('监督', 158),
#  ('扩大开放', 158),
#  ('展示', 158),
#  ('共赢', 158),
#  ('有效', 157),
#  ('互信', 157),
#  ('互联网', 156),
#  ('资源', 156),
#  ('加大', 156),
#  ('人员', 156),
#  ('2017', 156),
#  ('增进', 156),
#  ('救援', 156),
#  ('包括', 155),
#  ('委员', 155),
#  ('确保', 154),
#  ('不同', 154),
#  ('指导', 154),
#  ('近年来', 154),
#  ('脱贫', 154),
#  ('深刻', 153),
#  ('工程', 153),
#  ('成功', 153),
#  ('人类', 153),
#  ('两国人民', 153),
#  ('不能', 152),
#  ('人文', 152),
#  ('经营', 151),
#  ('良好', 150),
#  ('银行', 150),
#  ('介绍', 150),
#  ('制定', 150),
#  ('了解', 149),
#  ('条例', 148),
#  ('不会', 147),
#  ('综合', 145),
#  ('座谈会', 145),
#  ('国内', 144),
#  ('经贸', 144),
#  ('21', 144),
#  ('能源', 143),
#  ('13', 143),
#  ('力量', 142),
#  ('面临', 142),
#  ('主题', 142),
#  ('小微', 141),
#  ('获得', 141),
#  ('达成', 141),
#  ('做好', 140),
#  ('人才', 140),
#  ('出口', 140),
#  ('保护主义', 140),
#  ('体现', 138),
#  ('营造', 138),
#  ('密切', 138),
#  ('担当', 137),
#  ('意义', 137),
#  ('质量', 136),
#  ('成就', 136),
#  ('智慧', 135),
#  ('主动', 135),
#  ('非常', 135),
#  ('整改', 135),
#  ('越来越', 134),
#  ('注入', 134),
#  ('决定', 134),
#  ('充分', 133),
#  ('农村', 133),
#  ('就业', 133),
#  ('广泛', 133),
#  ('中巴', 133),
#  ('规模', 132),
#  ('力度', 132),
#  ('探索', 132),
#  ('联合国', 132),
#  ('意见', 131),
#  ('必须', 131),
#  ('互联互通', 131),
#  ('共同体', 131),
#  ('得到', 131),
#  ('主持', 130),
#  ('正式', 130),
#  ('民族', 130),
#  ('平等', 130),
#  ('亚太经合组织', 130),
#  ('长期', 129),
#  ('多个', 129),
#  ('深化改革', 129),
#  ('朋友', 129),
#  ('巨大', 128),
#  ('美国', 128),
#  ('广西', 128),
#  ('对接', 128),
#  ('一系列', 127),
#  ('变化', 127),
#  ('能够', 127),
#  ('16', 127),
#  ('展览', 127),
#  ('试验区', 127),
#  ('条件', 126),
#  ('党组织', 126),
#  ('数字', 126),
#  ('负责人', 125),
#  ('王毅', 125),
#  ('主任', 124),
#  ('经济社会', 123),
#  ('面对', 123),
#  ('双边关系', 123),
#  ('多边贸易', 123),
#  ('东亚', 123),
#  ('首次', 123),
#  ('围绕', 122),
#  ('今天', 122),
#  ('媒体', 122),
#  ('澳门', 122),
#  ('高度', 121),
#  ('框架', 121),
#  ('符合', 120),
#  ('两个', 119),
#  ('执行', 119),
#  ('起来', 119),
#  ('贯彻', 119),
#  ('高度重视', 119),
#  ('中华民族', 119),
#  ('发展中国家', 119),
#  ('决心', 118),
#  ('培训', 118),
#  ('明确', 118),
#  ('坚决', 118),
#  ('主义', 118),
#  ('十国集团', 118),
#  ('人类命运共同体', 118),
#  ('自贸', 118),
#  ('莫尔兹比港', 117),
#  ('设立', 117),
#  ('阶段', 116),
#  ('现代化', 116),
#  ('决策', 116),
#  ('社区', 116),
#  ('执法', 116),
#  ('致力于', 116),
#  ('人工智能', 115),
#  ('广大', 115),
#  ('平衡', 115),
#  ('日至', 115),
#  ('降低', 114),
#  ('过程', 114),
#  ('14', 114),
#  ('中西', 114),
#  ('形势', 113),
#  ('相信', 113),
#  ('妇女', 113),
#  ('导向', 112),
#  ('传统', 112),
#  ('成本', 112),
#  ('单位', 112),
#  ('协议', 112),
#  ('部长', 112),
#  ('相互尊重', 112),
#  ('有力', 111),
#  ('贷款', 111),
#  ('巩固', 111),
#  ('联系', 111),
#  ('南海', 111),
#  ('宣布', 110),
#  ('很多', 110),
#  ('达到', 109),
#  ('多年', 109),
#  ('军事', 109),
#  ('海上', 109),
#  ('需求', 108),
#  ('监管', 108),
#  ('看到', 108),
#  ('28', 108),
#  ('模式', 108),
#  ('进步', 107),
#  ('巴布亚新几内亚', 107),
#  ('督察', 107),
#  ('幼儿园', 107),
#  ('现在', 106),
#  ('各类', 106),
#  ('统一', 106),
#  ('成员', 106),
#  ('融合', 105),
#  ('命运', 105),
#  ('增加', 105),
#  ('实践', 105),
#  ('一体化', 105),
#  ('参展', 105),
#  ('协定', 105),
#  ('18', 104),
#  ('资金', 104),
#  ('选择', 104),
#  ('内容', 104),
#  ('美好', 104),
#  ('革命', 103),
#  ('关键', 103),
#  ('系统', 103),
#  ('审批', 103),
#  ('转型', 103),
#  ('接受', 103),
#  ('贯彻落实', 103),
#  ('文件', 103),
#  ('村民', 103),
#  ('邀请', 103),
#  ('工业', 103),
#  ('第二', 103),
#  ('造福', 103),
#  ('现场', 102),
#  ('实际', 102),
#  ('建成', 102),
#  ('十八', 102),
#  ('合作伙伴', 102),
#  ('丰富', 102),
#  ('伙伴关系', 102),
#  ('巴基斯坦', 102),
#  ('中文', 102),
#  ('讲话', 101),
#  ('数据', 101),
#  ('结合', 101),
#  ('出台', 101),
#  ('及时', 101),
#  ('这一', 101),
#  ('元首', 101),
#  ('巡视', 100),
#  ('习近平新时代中国特色社会主义思想', 100),
#  ('范围', 100),
#  ('27', 100),
#  ('再次', 99),
#  ('科学', 99),
#  ('汽车', 99),
#  ('关心', 99),
#  ('影响', 98),
#  ('创业', 98),
#  ('22', 98),
#  ('改善', 97),
#  ('切实', 97),
#  ('过去', 97),
#  ('一次', 97),
#  ('协商', 97),
#  ('党委', 97),
#  ('展现', 97),
#  ('民众', 96),
#  ('依法', 96),
#  ('规范', 96),
#  ('感谢', 96),
#  ('动能', 95),
#  ('信息', 95),
#  ('发生', 95),
#  ('非公有制', 95),
#  ('联合', 95),
#  ('广阔', 95),
#  ('利用', 95),
#  ('集体', 94),
#  ('来到', 94),
#  ('直接', 94),
#  ('给予', 94),
#  ('运行', 94),
#  ('大会', 94),
#  ('普惠', 94),
#  ('19', 94),
#  ('署名文章', 94),
#  ('遇到', 93),
#  ('金融机构', 93),
#  ('双边', 93),
#  ('贫困', 93),
#  ('有利于', 93),
#  ('发现', 93),
#  ('支撑', 92),
#  ('带动', 92),
#  ('采取', 92),
#  ('谈判', 92),
#  ('学前教育', 92),
#  ('地位', 92),
#  ('便利化', 92),
#  ('意识', 92),
#  ('规定', 92),
#  ('复兴', 92),
#  ('韩正', 92),
#  ('方案', 91),
#  ('感受', 91),
#  ('如今', 91),
#  ('主体', 91),
#  ('正确', 91),
#  ('俄罗斯', 91),
#  ('培育', 90),
#  ('机会', 90),
#  ('存在', 90),
#  ('报告', 90),
#  ('聚焦', 90),
#  ('二是', 90),
#  ('一流', 90),
#  ('有限公司', 89),
#  ('一是', 89),
#  ('潜力', 89),
#  ('大势', 89),
#  ('历程', 89),
#  ('文明', 89),
#  ('每年', 89),
#  ('APEC', 89),
#  ('刘少奇', 89),
#  ('吸引', 89),
#  ('精准', 88),
#  ('总体', 88),
#  ('亚洲', 88),
#  ('23', 88),
#  ('专业', 88),
#  ('青年', 88),
#  ('全方位', 88),
#  ('建议', 87),
#  ('开发', 87),
#  ('激发', 87),
#  ('中小企业', 87),
#  ('试点', 87),
#  ('奥尼尔', 87),
#  ('历史性', 87),
#  ('调整', 87),
#  ('赞赏', 86),
#  ('十九', 86),
#  ('使用', 86),
#  ('去年', 86),
#  ('主张', 86),
#  ('采访', 86),
#  ('拥有', 86),
#  ('中国共产党', 86),
#  ('热烈', 86),
#  ('契机', 85),
#  ('确定', 85),
#  ('资本', 85),
#  ('重视', 85),
#  ('29', 85),
#  ('助力', 85),
#  ('体验', 85),
#  ('中华人民共和国', 85),
#  ('17', 85),
#  ('消费', 84),
#  ('竞争力', 84),
#  ('秉持', 84),
#  ('经贸合作', 84),
#  ('时期', 84),
#  ('关注', 84),
#  ('汪洋', 84),
#  ('中欧', 84),
#  ('巴拿马', 84),
#  ('统筹', 83),
#  ('明年', 83),
#  ('负责', 83),
#  ('涉及', 83),
#  ('三是', 83),
#  ('十分', 83),
#  ('四个', 83),
#  ('中共', 83),
#  ('一起', 83),
#  ('25', 83),
#  ('新一轮', 82),
#  ('认识', 82),
#  ('法律', 82),
#  ('合理', 82),
#  ('事项', 82),
#  ('人民币', 82),
#  ('非正式', 82),
#  ('世界贸易组织', 82),
#  ('改变', 82),
#  ('着力', 81),
#  ('强大', 81),
#  ('研发', 81),
#  ('网络', 81),
#  ('知识产权', 81),
#  ('乡村', 81),
#  ('累计', 80),
#  ('大型', 80),
#  ('民间', 80),
#  ('收入', 80),
#  ('投入', 80),
#  ('广东', 80),
#  ('自信', 80),
#  ('世纪', 80),
#  ('计划', 80),
#  ('开创', 80),
#  ('矛盾', 79),
#  ('单边主义', 79),
#  ('马德里', 79),
#  ('葡萄牙', 79),
#  ('自主', 78),
#  ('出现', 78),
#  ('坚定不移', 78),
#  ('大国', 78),
#  ('健全', 78),
#  ('走向', 78),
#  ('外交', 78),
#  ('尔特', 78),
#  ('新闻', 77),
#  ('表明', 77),
#  ('一批', 77),
#  ('全省', 77),
#  ('庆祝', 77),
#  ('发布', 77),
#  ('业务', 77),
#  ('调研', 77),
#  ('年前', 77),
#  ('党建', 77),
#  ('100', 77),
#  ('一直', 77),
#  ('宣传', 77),
#  ('上午', 77),
#  ('此访', 77),
#  ('融资难', 76),
#  ('董事长', 76),
#  ('行业', 76),
#  ('党组', 76),
#  ('机场', 76),
#  ('安排', 76),
#  ('实行', 76),
#  ('积极参与', 76),
#  ('派驻', 76),
#  ('福祉', 76),
#  ('北斗', 76),
#  ('具体', 75),
#  ('使命', 75),
#  ('之间', 75),
#  ('下午', 74),
#  ('认真', 74),
#  ('听取', 74),
#  ('充分发挥', 74),
#  ('分享', 74),
#  ('先进', 74),
#  ('浙江', 74),
#  ('亿美元', 74),
#  ('党和国家', 74),
#  ('凝聚', 74),
#  ('经济体', 74),
#  ('人口', 74),
#  ('自由化', 74),
#  ('高层', 74),
#  ('经历', 74),
#  ('大海', 74),
#  ('杜特', 74),
#  ('结构', 73),
#  ('多家', 73),
#  ('一步', 73),
#  ('推广', 73),
#  ('集中', 73),
#  ('融入', 73),
#  ('做到', 73),
#  ('奋斗', 73),
#  ('中拉', 73),
#  ('紧密', 73),
#  ('贫困户', 73),
#  ('民生', 72),
#  ('告诉', 72),
#  ('独立', 72),
#  ('物流', 72),
#  ('自觉', 72),
#  ('尊重', 72),
#  ('共同努力', 72),
#  ('快速', 72),
#  ('成长', 72),
#  ('担任', 72),
#  ('设计', 72),
#  ('商品', 72),
#  ('理论', 71),
#  ('50', 71),
#  ('前景', 71),
#  ('26', 71),
#  ('抓好', 71),
#  ('纳入', 71),
#  ('公平', 71),
#  ('覆盖', 71),
#  ('相互', 71),
#  ('开启', 71),
#  ('卫星', 71),
#  ('格局', 70),
#  ('供给', 70),
#  ('绿色', 70),
#  ('同比', 70),
#  ('2016', 70),
#  ('基金', 70),
#  ('交易', 70),
#  ('跨境', 70),
#  ('必将', 70),
#  ('2019', 70),
#  ('推出', 70),
#  ('启动', 70),
#  ('参观', 70),
#  ('一致', 70),
#  ('产生', 69),
#  ('行为', 69),
#  ('国务委员', 69),
#  ('会谈', 69),
#  ('亲自', 69),
#  ('各界', 69),
#  ('成效', 68),
#  ('弘扬', 68),
#  ('考察', 68),
#  ('万元', 68),
#  ('故事', 68),
#  ('评价', 68),
#  ('各地', 68),
#  ('不少', 68),
#  ('杨洁篪', 68),
#  ('70', 68),
#  ('往来', 68),
#  ('一年', 68),
#  ('宗教', 68),
#  ('突破', 67),
#  ('各项', 67),
#  ('市场准入', 67),
#  ('前进', 67),
#  ('重申', 67),
#  ('与会', 67),
#  ('互鉴', 67),
#  ('24', 67),
#  ('公正', 67),
#  ('举行会谈', 67),
#  ('采购', 67),
#  ('系列', 67),
#  ('年底', 66),
#  ('种植', 66),
#  ('医疗', 66),
#  ('关切', 66),
#  ('开幕', 66),
#  ('公开', 66),
#  ('新型', 66),
#  ('中央军委', 66),
#  ('备忘录', 66),
#  ('讨论', 65),
#  ('部分', 65),
#  ('根本', 65),
#  ('处于', 65),
#  ('本次', 65),
#  ('互动', 65),
#  ('在内', 65),
#  ('拉美', 65),
#  ('大力', 65),
#  ('前行', 65),
#  ('深度', 64),
#  ('清单', 64),
#  ('严格', 64),
#  ('以下', 64),
#  ('强劲', 64),
#  ('迎来', 64),
#  ('见证', 64),
#  ('长远', 64),
#  ('秘书长', 64),
#  ('永远', 64),
#  ('人民政协', 64),
#  ('中共中央', 63),
#  ('因素', 63),
#  ('发出', 63),
#  ('协作', 63),
#  ('打开', 63),
#  ('大门', 63),
#  ('设置', 63),
#  ('展会', 63),
#  ('王岐山', 63),
#  ('丝绸之路', 63),
#  ('农民', 63),
#  ('游客', 63),
#  ('现代', 62),
#  ('养老', 62),
#  ('对此', 62),
#  ('处理', 62),
#  ('释放', 62),
#  ('铁路', 62),
#  ('标志', 62),
#  ('上升', 62),
#  ('市场主体', 62),
#  ('先后', 62),
#  ('数量', 62),
#  ('气候变化', 62),
#  ('海洋', 62),
#  ('现实', 62),
#  ('民企', 62),
#  ('运营', 62),
#  ('外国', 62),
#  ('制造', 62),
#  ('愿景', 62),
#  ('共商', 62),
#  ('日益', 62),
#  ('双方同意', 62),
#  ('各级', 61),
#  ('办好', 61),
#  ('近日', 61),
#  ('一条', 61),
#  ('激励', 61),
#  ('信号', 61),
#  ('分歧', 61),
#  ('行政', 61),
#  ('嘉宾', 61),
#  ('国王', 61),
#  ('消费者', 61),
#  ('便利', 61),
#  ('走廊', 61),
#  ('仪式', 61),
#  ('中共中央政治局', 60),
#  ('智能', 60),
#  ('设施', 60),
#  ('总结', 60),
#  ('减贫', 60),
#  ('有着', 60),
#  ('发展壮大', 60),
#  ('职责', 60),
#  ('组建', 60),
#  ('实际行动', 60),
#  ('客户', 60),
#  ('抵达', 60),
#  ('军队', 60),
#  ('稳步', 59),
#  ('局面', 59),
#  ('明显', 59),
#  ('进展', 59),
#  ('尽快', 59),
#  ('会上', 59),
#  ('国家级', 59),
#  ('磋商', 59),
#  ('先生', 59),
#  ('多次', 59),
#  ('人士', 59),
#  ('顺应', 59),
#  ('欧洲', 59),
#  ('谅解', 59),
#  ('应用', 58),
#  ('注重', 58),
#  ('反对', 58),
#  ('践行', 58),
#  ('学院', 58),
#  ('开放市场', 58),
#  ('改造', 58),
#  ('国际贸易', 58),
#  ('当今世界', 58),
#  ('效应', 57),
#  ('整体', 57),
#  ('家庭', 57),
#  ('环保', 57),
#  ('60', 57),
#  ('落地', 57),
#  ('第一个', 57),
#  ('基地', 57),
#  ('感到', 57),
#  ('战书', 57),
#  ('独特', 57),
#  ('大道', 57),
#  ('布局', 56),
#  ('适应', 56),
#  ('最好', 56),
#  ('加入', 56),
#  ('考核', 56),
#  ('治国', 56),
#  ('新篇章', 56),
#  ('高效', 56),
#  ('高兴', 56),
#  ('大量', 56),
#  ('红色', 56),
#  ('来华', 56),
#  ('2015', 56),
#  ('面向', 56),
#  ('特点', 55),
#  ('今年以来', 55),
#  ('培养', 55),
#  ('平稳', 55),
#  ('奇迹', 55),
#  ('税收', 55),
#  ('山东', 55),
#  ('结束', 55),
#  ('展区', 55),
#  ('布宜诺斯艾利斯', 55),
#  ('准备', 55),
#  ('应急', 55),
#  ('交通', 54),
#  ('配套', 54),
#  ('报道', 54),
#  ('发言', 54),
#  ('500', 54),
#  ('土地', 54),
#  ('态度', 54),
#  ('中央政治局常委', 54),
#  ('借鉴', 54),
#  ...]

# %%
import csv
with open('人民日报201811.csv','w')as f:
    mywriter=csv.writer(f)
    mywriter.writerows(sorted_wordcount)
f.close()
